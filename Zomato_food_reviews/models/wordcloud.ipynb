# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import os

# %%
#setting path to directory
csv_directory = "C:/Users/annar/OneDrive/Desktop/Visual Studio/GitHub/Projects2/Insighter/Zomato_food_reviews/Data"
os.chdir(csv_directory)

# %%
data = pd.read_csv("./csv_files/100N.csv")
data.head()
# Out:
#                                              Reviews
# 0                                          good food
# 1  Tasty and fresh! Very good portion size! Enjoy...
# 2  omlette and sauteed veggies were good. bread w...
# 3  Very nicely done..loved the custard fruit bowl...
# 4  Requested not to add onions, however it was no...

# %%
text = " ".join(word.split()[0] for word in data.Reviews)
text
# Out:
# "good Tasty omlette Very Requested need Amazing Worst Lettuce, I fruit I they club involve Worst If fruits Bread not food Zomato, considering less add Everything Chicken Yummy received The There all the Less bread expected should Quality You Bad Chicken Honestly there Worth Awesome! Even Too the Felt I it Best there Only please testy Stale The Please food There delivery sandwich Tasteless good delivered Variety Salad Bad wasn't I've Less rotten more delivery expensive, testy banna missed kiwi, description worst I I taste The testy Omelettes Definitely We more Perfect Will Fruits Pretty Paneer Worst taste food I'm Meal not strawberry Used I amazing' Toast small ok i Too horrible i they if Taste Spinach good I Extremely Good portion The Chicken good Don’t Added Gauva I how disappointed Sandwich Bevarshi quality great good received Everything fruit badhiya Club We #notvalyeformoney I The The the Not custard It’s falafel The I Till make innovate Very classic Pure The Not Fruits Not Alway
# ...

# %%
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)

# %%
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')

# %%
wc=WordCloud(stopwords=stop_words, collocations=False, max_font_size=55, max_words=100, background_color="black")
wc.generate(' '.join(data.Reviews))
plt.figure(figsize=(10,12))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
